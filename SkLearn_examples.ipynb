# %%
from sklearn import datasets
from sklearn import svm

digits = datasets.load_digits()
clf = svm.SVC(gamma=0.001, C=100.)

count = 10

clf.fit(digits.data[:-count], digits.target[:-count])

print(digits.target[-count:])
print(clf.predict(digits.data[-count:]))
# Out:
# [5 4 8 8 4 9 0 8 9 8]
# [5 4 8 8 4 9 0 8 9 8]
